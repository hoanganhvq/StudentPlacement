# %%
import pandas as pd 

df = pd.read_csv("../data/raw/global_placement.csv")
df.tail()
# Out:
#           cgpa  backlogs college_tier  country university_ranking_band  \
# 9995  8.040882         0       Tier 3      USA                 100-300
# 9996  5.401324         3       Tier 1       UK                 100-300
# 9997  6.435747         0       Tier 3       UK                    300+
# 9998  7.396612         1       Tier 3  Germany                 100-300
# 9999  7.515511         3       Tier 2       UK                    300+
#
#       internship_count  aptitude_score  communication_score specialization  \
# 9995                 2       98.120449            80.866213   Data Science
# 9996                 1       68.622854            83.458035   Data Science
# 9997                 2       69.067773            50.992745        Core CS
# 9998                 3       45.050463            86.807882          Cloud
# 9999                 4       66.947232            46.385843          AI/ML
#
#            industry  internship_quality_score placement_status         salary
# ...

# %%
df.isnull().sum()
# Out:
# cgpa                        0
# backlogs                    0
# college_tier                0
# country                     0
# university_ranking_band     0
# internship_count            0
# aptitude_score              0
# communication_score         0
# specialization              0
# industry                    0
# internship_quality_score    0
# placement_status            0
# salary                      0
# dtype: int64

# %%
df2 = pd.read_csv("../data/processed/X_train_cls.csv")
df2.head()
# Out:
#        cgpa  backlogs  college_tier  university_ranking_band  \
# 0  0.215717         1             3                        2
# 1 -0.747108         1             3                        3
# 2 -0.240648         1             2                        1
# 3 -1.544833         2             2                        2
# 4  0.697575         1             1                        3
#
#    internship_count  aptitude_score  communication_score  \
# 0         -0.404427       -0.850073            -0.702633
# 1         -0.404427       -0.027760             0.627973
# 2          1.258598       -1.194665            -0.049248
# 3         -0.404427        0.933572             0.100704
# 4         -1.235939        0.231974             1.525162
#
#    internship_quality_score  total_internship_value  academic_power  ...  \
# 0                 -0.994597               -0.589683        0.330592  ...
# 1                 -1.228953               -0.642129        1.220515  ...
# ...

# %%
df2 = pd.read_csv("../data/processed/X_train_reg.csv")
df2.head()
# Out:
#        cgpa  backlogs  college_tier  university_ranking_band  \
# 0  1.065830         2             3                        2
# 1  1.343270         2             1                        2
# 2  0.963315         1             3                        1
# 3  1.385722         0             2                        3
# 4 -1.099038         1             1                        2
#
#    internship_count  aptitude_score  communication_score  \
# 0          0.249300       -0.105787             1.137483
# 1          0.249300       -0.444688            -1.759029
# 2         -1.354691        0.269277             0.210508
# 3          1.853291        0.985752             2.276896
# 4         -0.552696       -0.268635             0.686170
#
#    internship_quality_score  total_internship_value  academic_power  ...  \
# 0                 -1.020578               -0.183484        0.451802  ...
# 1                  0.823792                0.575525        0.526379  ...
# ...
